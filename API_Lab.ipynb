# %%
import requests
import json
import collections
import pandas as pd
import os
from glob import glob
from datetime import timedelta
import time

import Campaing_WB_New, Create_Campaing_WB

API_KEY = "eyJhbGciOiJFUzI1NiIsImtpZCI6IjIwMjUwOTA0djEiLCJ0eXAiOiJKV1QifQ.eyJhY2MiOjEsImVudCI6MSwiZXhwIjoxNzc5OTk2ODQ4LCJpZCI6IjAxOWFjNDNiLWRjMDEtN2RlMS1iZWJjLTM0ZGVjNDE2NmI1MCIsImlpZCI6MTU4MTg5MDYsIm9pZCI6NDE2MTA2OCwicyI6MTYxMjYsInNpZCI6IjQ0OTAyOWU4LTkxYmItNDNhOC1iM2IyLTFkYTBhMmY3NjdiNSIsInQiOmZhbHNlLCJ1aWQiOjE1ODE4OTA2fQ.6xWz0isz52O--s6Ara1oYORzTB0r-4gTQX8YI610sYQUu3LzueK0m8ooyfCHw2rvBupqzV7wGJ4wIjIqi32-zA"

# %%
artikul.values[0]
# Out:
# 242929571

# %%
df_count = Campaing_WB_New.get_promotion_count_df(API_KEY)
# Out:
# Status code (count): 200
# ...

# %%
# for i in range(len(df_count)):
#     df_temp = df_count[i:i+49]
df_count = Campaing_WB_New.get_promotion_count_df(API_KEY)
df_adv = Campaing_WB_New.get_promotion_adverts_df(API_KEY, df_count)
df_campaings = Campaing_WB_New.build_final_df(df_count, df_adv)
# Out:
# Status code (count): 200
# ...

# %%
df_campaings

# %%
# Собираем все .xlsx файлы
files = glob(os.path.join("Товары/Товары ВБ", "*.xlsx"))

df_list = []
for file in files:
    # читаем, пропуская первую строку
    df_tmp = pd.read_excel(file, engine='calamine', skiprows=2)
    df_list.append(df_tmp)

# объединяем все файлы
df_all = pd.concat(df_list, ignore_index=True)
df_all.drop([0], inplace=True)
df_filter = df_all[~df_all['Артикул WB'].isin()]

for art in range(len(df_all[0:5000])):
    campaign_nms = [int(df_all[0:5000].sample()['Артикул WB'].values[0])]
    campaign_mask = f"Тест seacat через API {campaign_nms}"

    info = Create_Campaing_WB.create_and_pause_campaign(
        name=campaign_mask,
        nms=campaign_nms,
        bid_type="manual",              # или "unified"
        placement_types=["search"],     # для manual
    )
    print("Результат:")
    print(info)
    time.sleep(13) # 13 секунд ждём для след запроса
# Out:
# save-ad status: 400 {"error":"Invalid payload: request body processing error"}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[33], line 18
#      15 campaign_mask = "Тест seacat через API"
#      16 campaign_nms = df_all.sample()['Артикул WB'].values[0]
# ---> 18 info = Create_Campaing_WB.create_and_pause_campaign(
#      19     name=f"{campaign_mask}" + f"Артикула {campaign_nms}",
#      20     nms=campaign_nms,
#      21     bid_type="manual",              # или "unified"
#      22     placement_types=["search"],     # для manual
#      23 )
#      24 print("Результат:")
#      25 print(info)
#
# File c:\Users\i.taldykin\Documents\APITesting\Create_Campaing_WB.py:109, in create_and_pause_campaign(name, nms, bid_type, placement_types)
#      91 def create_and_pause_campaign(name: str,
#      92                               nms: list[int],
# ...
